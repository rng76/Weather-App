# %%
# Import the necessary libraries
from flask import Flask, render_template_string, request  # Flask for web framework and template rendering
import requests  # Requests for making HTTP requests to the weather API

# Initialize a Flask application
app = Flask(__name__)

# Function to fetch weather data for a given city
def get_weather(city):
    api_key = "437132f441922fcd0b44e0afa6b0eea5"  #OpenWeatherMap API key
    base_url = "http://api.openweathermap.org/data/2.5/weather"  # Base URL for the API

    params = {
        "q": city,  # City name
        "appid": api_key,  # API key
        "units": "imperial"  # Temperature in Fahrenheit
    }

    response = requests.get(base_url, params=params)  # Send GET request to the API

    if response.status_code == 200:
        return response.json()  # Return JSON data if the request is successful
    else:
        return None  # Return None if the request fails

# HTML template as a string for rendering the weather app interface
template = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Weather App</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            text-align: center;
            background-color: #f0f0f0;
        }
        .container {
            width: 50%;
            margin: auto;
            padding: 20px;
            background: white;
            border-radius: 8px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
        }
    </style>
</head>
<body>
    <div class="container">
        <h1>Weather App</h1>
        <form method="post">
            <input type="text" name="city" placeholder="Enter a city" required>
            <button type="submit">Get Weather</button>
        </form>
        
        {% if weather %}
            <h2>Weather in {{ weather['name'] }}:</h2>
            <p>Temperature: {{ weather['main']['temp'] }}°F</p>
            <p>Description: {{ weather['weather'][0]['description']|capitalize }}</p>
            <p>Humidity: {{ weather['main']['humidity'] }}%</p>
            <p>Wind Speed: {{ weather['wind']['speed'] }} m/s</p>
            <img src="http://openweathermap.org/img/wn/{{ weather['weather'][0]['icon'] }}@2x.png" alt="Weather Icon">
        {% elif error %}
            <p style="color:red;">{{ error }}</p>
        {% endif %}
    </div>
</body>
</html>
"""

# Route for the home page of the application
@app.route('/', methods=['GET', 'POST'])
def home():
    weather = None  # Initialize weather variable
    error = None  # Initialize error variable

    if request.method == 'POST':  # Check for POST request
        city = request.form.get('city')  # Get city name from the form
        weather = get_weather(city)  # Fetch weather data for the city

        if not weather:  # If no weather data is returned
            error = "City not found"  # Set error message

    return render_template_string(template, weather=weather, error=error)  # Render HTML template

# Run the Flask application
if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)  # Start the app
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
